# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
def gaussian(img):

# %%
img = mpimg.imread('./1.jpg')
plt.imshow(img)
plt.show()

# %%
img.shape
# Out:
# (433, 650, 3)
